# %% [markdown]
# ### Cardio Good Fitness Case Study - Descriptive Statistics
# The market research team at AdRight is assigned the task to identify the profile of the typical customer for each treadmill product offered by CardioGood Fitness.
# The market research team decides to investigate whether there are differences across the product lines with respect to customer characteristics.
# The team decides to collect data on individuals who purchased a treadmill at a CardioGoodFitness retail store during the prior three months.
# The data are stored in the CardioGoodFitness.csv file.
#
# #### The team identifies the following customer variables to study:
# * product purchased, TM195, TM498, or TM798;
# * gender;age, in years;
# * education, in years;
# * relationship status, single or partnered;
# * annual household income ;
# * average number of times the customer plans to use the treadmill each week;
# * average number of miles the customer expects to walk/run each week;
# * and self-rated fitness on an 1-to-5 scale, where 1 is poor shape and 5 is excellent shape.
#
# #### Perform descriptive analytics to create a customer profile for each CardioGood Fitness treadmill product line.
#
# ##### Data credit sourse - henry harvin education

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('Cardio_Good_Fitness.csv')

# %%
df.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
df.tail()
# Out:
#     Product  Age Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 175   TM798   40   Male         21        Single      6        5   83416
# 176   TM798   42   Male         18        Single      5        4   89641
# 177   TM798   45   Male         16        Single      5        5   90886
# 178   TM798   47   Male         18     Partnered      4        5  104581
# 179   TM798   48   Male         18     Partnered      4        5   95508
#
#      Miles
# 175    200
# 176    200
# 177    160
# 178    120
# 179    180

# %%
df.head(15)
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0    TM195   18    Male         14        Single      3        4   29562
# 1    TM195   19    Male         15        Single      2        3   31836
# 2    TM195   19  Female         14     Partnered      4        3   30699
# 3    TM195   19    Male         12        Single      3        3   32973
# 4    TM195   20    Male         13     Partnered      4        2   35247
# 5    TM195   20  Female         14     Partnered      3        3   32973
# 6    TM195   21  Female         14     Partnered      3        3   35247
# 7    TM195   21    Male         13        Single      3        3   32973
# 8    TM195   21    Male         15        Single      5        4   35247
# 9    TM195   21  Female         15     Partnered      2        3   37521
# 10   TM195   22    Male         14        Single      3        3   36384
# 11   TM195   22  Female         14     Partnered      3        2   35247
# ...

# %%
df.tail(15)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 165   TM798   29    Male         18        Single      5        5   52290
# 166   TM798   29    Male         14     Partnered      7        5   85906
# 167   TM798   30  Female         16     Partnered      6        5   90886
# 168   TM798   30    Male         18     Partnered      5        4  103336
# 169   TM798   30    Male         18     Partnered      5        5   99601
# 170   TM798   31    Male         16     Partnered      6        5   89641
# 171   TM798   33  Female         18     Partnered      4        5   95866
# 172   TM798   34    Male         16        Single      5        5   92131
# 173   TM798   35    Male         16     Partnered      4        5   92131
# 174   TM798   38    Male         18     Partnered      5        5  104581
# 175   TM798   40    Male         21        Single      6        5   83416
# 176   TM798   42    Male         18        Single      5        4   89641
# ...

# %%
df.sample()  # display 1 random row
# Out:
#    Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 43   TM195   27  Female         14     Partnered      2        3   45480
#
#     Miles
# 43     56

# %%
df.sample(10)
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 148   TM798   24  Female         16        Single      5        5   52291
# 144   TM798   23  Female         18        Single      5        4   53536
# 164   TM798   28    Male         18        Single      6        5   88396
# 129   TM498   35    Male         16     Partnered      3        2   53439
# 64    TM195   35  Female         16     Partnered      3        3   60261
# 87    TM498   23    Male         14     Partnered      3        3   36384
# 21    TM195   23    Male         16        Single      4        3   40932
# 137   TM498   40    Male         16     Partnered      3        3   64809
# 120   TM498   33    Male         13     Partnered      4        4   53439
# 110   TM498   26    Male         16        Single      4        3   51165
#
#      Miles
# 148    200
# 144    100
# 164    150
# 129     53
# 64      94
# 87      95
# 21      94
# 137     95
# 120    170
# 110    106

# %%
df.shape  # displays the shape of the data (row,column)
# Out:
# (180, 9)

# %%
df.describe()  # statistical data includes count, mean, std, min, 25%, 50%, 75%, max
# Out:
#               Age   Education       Usage     Fitness         Income  \
# count  180.000000  180.000000  180.000000  180.000000     180.000000
# mean    28.788889   15.572222    3.455556    3.311111   53719.577778
# std      6.943498    1.617055    1.084797    0.958869   16506.684226
# min     18.000000   12.000000    2.000000    1.000000   29562.000000
# 25%     24.000000   14.000000    3.000000    3.000000   44058.750000
# 50%     26.000000   16.000000    3.000000    3.000000   50596.500000
# 75%     33.000000   16.000000    4.000000    4.000000   58668.000000
# max     50.000000   21.000000    7.000000    5.000000  104581.000000
#
#             Miles
# count  180.000000
# mean   103.194444
# std     51.863605
# min     21.000000
# 25%     66.000000
# 50%     94.000000
# 75%    114.750000
# max    360.000000

# %%
df.describe(include="all") # this includes all the description of the data
# Out:
#        Product         Age Gender   Education MaritalStatus       Usage  \
# count      180  180.000000    180  180.000000           180  180.000000
# unique       3         NaN      2         NaN             2         NaN
# top      TM195         NaN   Male         NaN     Partnered         NaN
# freq        80         NaN    104         NaN           107         NaN
# mean       NaN   28.788889    NaN   15.572222           NaN    3.455556
# std        NaN    6.943498    NaN    1.617055           NaN    1.084797
# min        NaN   18.000000    NaN   12.000000           NaN    2.000000
# 25%        NaN   24.000000    NaN   14.000000           NaN    3.000000
# 50%        NaN   26.000000    NaN   16.000000           NaN    3.000000
# 75%        NaN   33.000000    NaN   16.000000           NaN    4.000000
# max        NaN   50.000000    NaN   21.000000           NaN    7.000000
#
#            Fitness         Income       Miles
# count   180.000000     180.000000  180.000000
# ...

# %%
df.info()  # displays the data types
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 180 entries, 0 to 179
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Product        180 non-null    object
#  1   Age            180 non-null    int64
#  2   Gender         180 non-null    object
#  3   Education      180 non-null    int64
#  4   MaritalStatus  180 non-null    object
#  5   Usage          180 non-null    int64
#  6   Fitness        180 non-null    int64
#  7   Income         180 non-null    int64
#  8   Miles          180 non-null    int64
# dtypes: int64(6), object(3)
# memory usage: 12.8+ KB

# %%
df.isnull().sum()   # sum of null values
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
df.dtypes    # data types
# Out:
# Product          object
# Age               int64
# Gender           object
# Education         int64
# MaritalStatus    object
# Usage             int64
# Fitness           int64
# Income            int64
# Miles             int64
# dtype: object

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df.hist(figsize=(15,25)) # histogram with manual figure size (it is used for numerical data only)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>,
#         <AxesSubplot:title={'center':'Education'}>],
#        [<AxesSubplot:title={'center':'Usage'}>,
#         <AxesSubplot:title={'center':'Fitness'}>],
#        [<AxesSubplot:title={'center':'Income'}>,
#         <AxesSubplot:title={'center':'Miles'}>]], dtype=object)

# %%
import seaborn as sns

sns.boxplot(x="Gender", y="Age", data=df) ## it is used for box plot (one should be numerical data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Age'>

# %%
sns.boxplot(x="MaritalStatus", y="Age", data=df)
# Out:
# <AxesSubplot:xlabel='MaritalStatus', ylabel='Age'>

# %%
pd.crosstab(df['Product'],df['Gender'] )  # crosstab is used for counting two catagorical data
# Out:
# Gender   Female  Male
# Product
# TM195        40    40
# TM498        29    31
# TM798         7    33

# %%
pd.crosstab(df['Product'],df['MaritalStatus'] )  # crosstab is used for counting two catagorical data
# Out:
# MaritalStatus  Partnered  Single
# Product
# TM195                 48      32
# TM498                 36      24
# TM798                 23      17

# %%
sns.countplot(x="Product", hue="Gender", data=df)   # countplot is used for counting two catagorical data
# Out:
# <AxesSubplot:xlabel='Product', ylabel='count'>

# %%
pd.pivot_table(df, index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'], aggfunc=len)   # Pandas is used t create pivot table
# Out:
#                      Age        Education          Fitness           Income  \
# MaritalStatus  Partnered Single Partnered Single Partnered Single Partnered
# Product Gender
# TM195   Female        27     13        27     13        27     13        27
#         Male          21     19        21     19        21     19        21
# TM498   Female        15     14        15     14        15     14        15
#         Male          21     10        21     10        21     10        21
# TM798   Female         4      3         4      3         4      3         4
#         Male          19     14        19     14        19     14        19
#
#                           Miles            Usage
# MaritalStatus  Single Partnered Single Partnered Single
# Product Gender
# TM195   Female     13        27     13        27     13
#         Male       19        21     19        21     19
# TM498   Female     14        15     14        15     14
# ...

# %%
pd.pivot_table(df,'Income', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus      Partnered        Single
# Product Gender
# TM195   Female  46153.777778  45742.384615
#         Male    50028.000000  43265.842105
# TM498   Female  49724.800000  48920.357143
#         Male    49378.285714  47071.800000
# TM798   Female  84972.250000  58516.000000
#         Male    81431.368421  68216.428571

# %%
pd.pivot_table(df,'Miles', index=['Product', 'Gender'],
                     columns=[ 'MaritalStatus'])
# Out:
# MaritalStatus    Partnered      Single
# Product Gender
# TM195   Female   74.925926   78.846154
#         Male     80.190476   99.526316
# TM498   Female   94.000000   80.214286
#         Male     87.238095   91.100000
# TM798   Female  215.000000  133.333333
#         Male    176.315789  147.571429

# %%
sns.pairplot(df, diag_kind='kde')

# %%
df['Age'].std()   # it is used to calculate standard deviation
# Out:
# 6.943498135399795

# %%
df['Age'].mean()   # maean

# %%
df.hist(by='Gender',column = 'Age')   # histogram
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
df.hist(by='Gender',column = 'Income')  # histogram
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
df.hist(by='Gender',column = 'Miles')   # histogram
# Out:
# array([<AxesSubplot:title={'center':'Female'}>,
#        <AxesSubplot:title={'center':'Male'}>], dtype=object)

# %%
df.hist(by='Product',column = 'Miles')  # histogram
# Out:
# array([[<AxesSubplot:title={'center':'TM195'}>,
#         <AxesSubplot:title={'center':'TM498'}>],
#        [<AxesSubplot:title={'center':'TM798'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
correlation = mydata.corr()         # to find correlation
correlation
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(correlation,annot=True)  # heatmap
# Out:
# <AxesSubplot:>
